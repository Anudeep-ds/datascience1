# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.2

# %%
d=pd.read_csv("D:\\python\\datasets\\StudentsPerformance.csv")
df=pd.DataFrame(d)
print(df)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
di={"Name":["abc","def","ghi"],"Roll No":[1,2,3],"per":[90.5,89.4,96]}
df=pd.DataFrame(di)
df
# Out:
#   Name  Roll No   per
# 0  abc        1  90.5
# 1  def        2  89.4
# 2  ghi        3  96.0

# %% [markdown]
# list of tuples

# %%
l=[("abc",12,89.2),("dfc",11,99.2),("klk",19,79.2)]
df=pd.DataFrame(l)
df
# Out:
#      0   1     2
# 0  abc  12  89.2
# 1  dfc  11  99.2
# 2  klk  19  79.2

# %%
d=pd.read_csv("D:\\python\\datasets\\StudentsPerformance.csv")
df=pd.DataFrame(d)
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df[0:100:4]
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 0   female        group B           bachelor's degree      standard
# 4     male        group C                some college      standard
# 8     male        group D                 high school  free/reduced
# 12  female        group B                 high school      standard
# 16    male        group C                 high school      standard
# 20    male        group D                 high school      standard
# 24    male        group D           bachelor's degree  free/reduced
# 28    male        group C                 high school      standard
# 32  female        group E             master's degree  free/reduced
# 36  female        group D          associate's degree      standard
# 40    male        group C          associate's degree  free/reduced
# 44  female        group E          associate's degree  free/reduced
# 48  female        group D          associate's degree  free/reduced
# ...

# %% [markdown]
# column tho call cheyataniki kindha sytax use chestham

# %%
df["lunch"]
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
df[["lunch","math score"]][0:50:2]
# Out:
#            lunch  math score
# 0       standard          72
# 2       standard          90
# 4       standard          76
# 6       standard          88
# 8   free/reduced          64
# 10      standard          58
# 12      standard          65
# 14      standard          50
# 16      standard          88
# 18  free/reduced          46
# 20      standard          66
# 22      standard          44
# 24  free/reduced          74
# 26      standard          69
# 28      standard          70
# 30      standard          69
# 32  free/reduced          56
# 34      standard          97
# 36      standard          74
# 38  free/reduced          75
# 40  free/reduced          55
# 42      standard          53
# 44  free/reduced          50
# 46      standard          55
# 48  free/reduced          57

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, gender                                    female
# race/ethnicity                           group B
# parental level of education    bachelor's degree
# lunch                                   standard
# test preparation course                     none
# math score                                    72
# reading score                                 72
# writing score                                 74
# Name: 0, dtype: object)
# (1, gender                               female
# race/ethnicity                      group C
# parental level of education    some college
# lunch                              standard
# test preparation course           completed
# math score                               69
# reading score                            90
# writing score                            88
# Name: 1, dtype: object)
# (2, gender                                  female
# race/ethnicity                         group B
# parental level of education    master's degree
# ...

# %% [markdown]
# LOC and iLOC v impotant

# %%
df.loc[211]
# Out:
# gender                                 male
# race/ethnicity                      group C
# parental level of education    some college
# lunch                          free/reduced
# test preparation course                none
# math score                               35
# reading score                            28
# writing score                            27
# Name: 211, dtype: object

# %%
df.loc[231,["gender","lunch"]]
# Out:
# gender        male
# lunch     standard
# Name: 231, dtype: object

# %%
df.loc[0:5]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
df.loc[0:211,["gender","lunch"]]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 207    male      standard
# 208  female  free/reduced
# 209  female  free/reduced
# 210    male  free/reduced
# 211    male  free/reduced
#
# [212 rows x 2 columns]

# %%
df.loc[0:5,"gender":"writing score"]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
